# %%
import _init_paths
from datasets.factory import get_imdb
import cv2
import visdom
import numpy as np
from PIL import Image
# vis = visdom.Visdom(server='http://localhost',port='8097')
imdb = get_imdb('voc_2007_trainval')
imdb.classes
idx =2018
img_path = imdb.image_path_at(idx)
img = cv2.imread(img_path)
img_pil = Image.open(img_path)
print list(img_pil.getdata())
roidb = imdb.roidb
print len(roidb)
boxes = roidb[idx]['boxes']
print boxes.shape
for box in boxes[:10,:]:
    cv2.rectangle(img,(box[0],box[1]),(box[2],box[3]),(0,0,255),3)
data = np.asarray(img)
data = np.transpose(data, [2,0,1])
# data = data +img
# vis.image(data)

# from matplotlib import pyplot as plt
# plt.imshow(img)
# plt.show()    
print imdb.num_images
# Out:
# [(127, 133, 133), (124, 130, 130), (120, 126, 126), (121, 125, 126), (119, 123, 124), (114, 118, 119), (109, 113, 116), (101, 104, 109), (96, 99, 106), (97, 100, 109), (97, 100, 109), (96, 99, 108), (97, 100, 109), (99, 103, 112), (110, 115, 121), (125, 130, 136), (137, 155, 165), (171, 189, 199), (196, 213, 223), (219, 233, 246), (225, 237, 249), (240, 250, 255), (240, 248, 255), (247, 254, 255), (246, 251, 255), (252, 255, 255), (252, 253, 255), (254, 254, 254), (252, 252, 250), (254, 254, 252), (254, 253, 251), (253, 252, 250), (254, 253, 255), (254, 252, 255), (253, 251, 254), (253, 251, 252), (255, 252, 253), (255, 251, 250), (255, 251, 250), (255, 252, 249), (255, 252, 249), (255, 252, 251), (254, 253, 251), (255, 253, 254), (254, 254, 254), (253, 254, 255), (253, 254, 255), (251, 255, 255), (250, 254, 253), (251, 255, 254), (252, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (253, 255, 254), (253, 255, 254), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (254, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 254, 255), (255, 254, 255), (255, 254, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 255, 255), (255, 252, 253), (255, 253, 255), (253, 253, 253), (252, 255, 255), (251, 255, 252), (249, 254, 248), (253, 255, 249), (254, 255, 250), (245, 246, 250), (233, 237, 248), (220, 228, 247), (193, 205, 229), (182, 194, 220), (153, 163, 188), (138, 146, 169), (133, 138, 158), (137, 149, 165), (137, 149, 165), (136, 148, 162), (134, 146, 158), (131, 144, 153), (130, 143, 151), (129, 142, 148), (127, 140, 146), (129, 140, 144), (127, 138, 142), (125, 134, 141), (125, 132, 140), (124, 128, 139), (121, 125, 137), (119, 121, 134), (117, 119, 132), (127, 129, 141), (126, 128, 140), (123, 125, 137), (124, 126, 138), (126, 129, 138), (125, 129, 138), (126, 130, 139), (124, 129, 135), (125, 130, 136), (126, 131, 137), (128, 133, 137), (129, 134, 138), (129, 134, 138), (128, 133, 137), (130, 135, 139), (133, 138, 142), (137, 139, 138), (136, 137, 139), (135, 139, 140), (136, 140, 141), (133, 138, 141), (132, 137, 140), (135, 140, 144), (135, 143, 146), (135, 143, 146), (134, 142, 145), (137, 142, 146), (137, 142, 146), (138, 143, 146), (139, 143, 146), (138, 142, 145), (137, 141, 142), (133, 143, 142), (133, 143, 142), (133, 143, 142), (134, 144, 143), (133, 143, 144), (132, 142, 143), (131, 141, 142), (131, 141, 143), (131, 141, 143), (130, 140, 142), (131, 141, 143), (133, 142, 147), (134, 143, 148), (132, 141, 146), (129, 136, 142), (126, 133, 139), (122, 129, 137), (122, 129, 137), (122, 129, 135), (122, 129, 135), (122, 129, 135), (123, 133, 135), (127, 137, 139), (130, 140, 142), (128, 138, 140), (130, 140, 142), (133, 143, 145), (134, 144, 146), (132, 141, 146), (130, 137, 143), (126, 133, 139), (124, 131, 137), (125, 134, 141), (120, 129, 136), (123, 132, 139), (127, 136, 143), (126, 133, 141), (127, 134, 142), (131, 138, 146), (131, 138, 146), (131, 138, 144), (131, 138, 146), (134, 138, 147), (136, 140, 149), (133, 140, 148), (130, 137, 145), (129, 136, 144), (129, 136, 144), (129, 133, 142), (126, 130, 139), (128, 132, 141), (127, 130, 139), (127, 130, 139), (124, 127, 136), (124, 127, 136), (121, 124, 133), (119, 122, 131), (119, 122, 131), (118, 122, 131), (120, 124, 1 ...
# voc_2007_trainval ss roidb loaded from /home/studio/Documents/aman/crystal_test/hw2-release/code/data/cache/voc_2007_trainval_selective_search_roidb.pkl
# 5011
# (2853, 4)
# 5011

# %%
gt_roidb = imdb.gt_roidb()
gt_boxes = gt_roidb[2018]['boxes']
print gt_boxes.shape
for bbox in gt_boxes:
    cv2.rectangle(img, (box[0],box[1]),(box[2],box[3]), (0, 204, 0), 2)
# plt.imshow(img)
# plt.show()
data = np.asarray(img)
data = np.transpose(data, [2,0,1])
# vis.image(data)
gt_roidb[30]['gt_classes']
# Out:
# voc_2007_trainval gt roidb loaded from /home/studio/Documents/aman/crystal_test/hw2-release/code/data/cache/voc_2007_trainval_gt_roidb.pkl
# (1, 4)
# array([19], dtype=int32)

# %%
gt_roidb[30]['gt_classes']
# Out:
# array([12,  9], dtype=int32)

# %%
print np.asarray(img_pil.getdata())
# Out:
# [[127 133 133]
#  [124 130 130]
#  [120 126 126]
#  ...,
#  [131 126 123]
#  [133 128 125]
#  [128 123 120]]

# %%
imdb.classes
# Out:
# ('aeroplane',
#  'bicycle',
#  'bird',
#  'boat',
#  'bottle',
#  'bus',
#  'car',
#  'cat',
#  'chair',
#  'cow',
#  'diningtable',
#  'dog',
#  'horse',
#  'motorbike',
#  'person',
#  'pottedplant',
#  'sheep',
#  'sofa',
#  'train',
#  'tvmonitor')

# %%
np.asarray(list(img_pil.getdata())).max()
# Out:
# 255
